# %%
import pandas as pd

# %%
df = pd.read_excel('../data/ellipses_nodup_20220804_174013.xlsx')

# %%
df
# Out:
#       Unnamed: 0                                   file  sentence_id  \
# 0              0        00_mundhoehlenkarzinom_0002.tsv            1
# 1              1        00_mundhoehlenkarzinom_0002.tsv            2
# 2              2        00_mundhoehlenkarzinom_0002.tsv            5
# 3              3        00_mundhoehlenkarzinom_0005.tsv           12
# 4              4        00_mundhoehlenkarzinom_0005.tsv           18
# ...          ...                                    ...          ...
# 4652        4652  29_adulte-weichgewebesarkome_0397.tsv            4
# 4653        4653  29_adulte-weichgewebesarkome_0397.tsv            6
# 4654        4654  29_adulte-weichgewebesarkome_0403.tsv            1
# 4655        4655  29_adulte-weichgewebesarkome_0404.tsv            6
# 4656        4656  29_adulte-weichgewebesarkome_0405.tsv            3
#
#       fragment                                      full_sentence  \
# 0         True  ['Hauptrisikofaktoren', 'für', 'das', 'Auftret...
# ...
